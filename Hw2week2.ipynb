# %% [markdown]
# <a href="https://colab.research.google.com/github/asianmouse/Data-201-labs/blob/main/Hw2week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Before reading the data into Python, it can be viewed in Excel or a text editor.
# (a) Use the pd.read_csv() function to read the data into Python. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.
# (b) Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the first column is just the name of each university in a column named something like Unnamed: 0. We don't really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at the resulting data frames:
#
#
#
# ---

# %% [markdown]
# A.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# B

# %%
college= pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/College.csv")

# %%
college2= pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/College.csv", index_col=0)
college3 = college.rename ({ 'Unnamed: 0': 'College'}, axis=1)
college3 = college3.set_index ('College')

# %%
college=college3

# %% [markdown]
# C

# %%
college3.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# D

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# E

# %%
college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# F

# %%
college['Elite'] = pd.cut(college['Top10perc'],
                           [0, 50, 100],
                           labels=['No', 'Yes'])

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# G

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(10, 8))

college['Apps'].plot.hist(ax=axes[0, 0], bins=10)


college['Apps'].plot.hist(ax=axes[0, 1], bins=30)


college['Outstate'].plot.hist(ax=axes[1, 0], bins=10)


college['Outstate'].plot.hist(ax=axes[1, 1], bins=30)


plt.tight_layout()
plt.show()

# %% [markdown]
# H

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

college['Room.Board'].plot.hist(ax=axes[0, 0], bins=10)


college['Room.Board'].plot.hist(ax=axes[0, 1], bins=30)


college['Enroll'].plot.hist(ax=axes[1, 0], bins=10)


college['Enroll'].plot.hist(ax=axes[1, 1], bins=30)


plt.show()

# %% [markdown]
# Looking at the two graphs on the top, distribution is roughly bell-shaped, centered around $4,000–4,500 with a mild right skew. While the two bottom graphs are heavily right-skewed. There is a few small secondary bumps around 2,500 and 3,000–3,500, hinting that within the "smaller schools" majority there may be sub-groups rather than one uniform population.

# %% [markdown]
# 9

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Auto = pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/Auto.csv")

# %%
Auto = Auto.replace("?", pd.NA)

# %%
Auto.shape
Auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
Auto["horsepower"] = pd.to_numeric(Auto["horsepower"])

# %% [markdown]
# A

# %% [markdown]
# Cylinders, year, origin, name are qualitative and the rest are quantitative I believe.

# %% [markdown]
# B

# %%
Auto[["mpg", "displacement", "horsepower", "weight", "acceleration"]].describe()
# Out:
#               mpg  displacement  horsepower       weight  acceleration
# count  397.000000    397.000000  392.000000   397.000000    397.000000
# mean    23.515869    193.532746  104.469388  2970.261965     15.555668
# std      7.825804    104.379583   38.491160   847.904119      2.749995
# min      9.000000     68.000000   46.000000  1613.000000      8.000000
# 25%     17.500000    104.000000   75.000000  2223.000000     13.800000
# 50%     23.000000    146.000000   93.500000  2800.000000     15.500000
# 75%     29.000000    262.000000  126.000000  3609.000000     17.100000
# max     46.600000    455.000000  230.000000  5140.000000     24.800000

# %%
Auto["mpg"].max()-Auto["mpg"].min()
# Out:
# 37.6

# %%
Auto["displacement"].max()-Auto["displacement"].min()
# Out:
# 387.0

# %%
Auto["horsepower"].max()-Auto["horsepower"].min()
# Out:
# 184.0

# %%
Auto["weight"].max()-Auto["weight"].min()
# Out:
# 3527

# %%
Auto["acceleration"].max()-Auto["acceleration"].min()
# Out:
# 16.8

# %% [markdown]
# C

# %%
Auto[["mpg", "displacement", "horsepower", "weight", "acceleration"]].mean()
# Out:
# mpg               23.515869
# displacement     193.532746
# horsepower       104.469388
# weight          2970.261965
# acceleration      15.555668
# dtype: float64

# %%
Auto[["mpg", "displacement", "horsepower", "weight", "acceleration"]].std()
# Out:
# mpg               7.825804
# displacement    104.379583
# horsepower       38.491160
# weight          847.904119
# acceleration      2.749995
# dtype: float64

# %% [markdown]
# D

# %%
Auto_1085 = Auto.drop(Auto.index[9:85])
(Auto_1085.shape)
# Out:
# (321, 9)

# %%
Auto_1085[["mpg", "displacement", "horsepower", "weight", "acceleration"]].describe()
# Out:
#               mpg  displacement  horsepower       weight  acceleration
# count  321.000000    321.000000  317.000000   321.000000    321.000000
# mean    24.438629    187.049844  100.955836  2933.962617     15.723053
# std      7.908184     99.635385   35.895567   810.642938      2.680514
# min     11.000000     68.000000   46.000000  1649.000000      8.500000
# 25%     18.000000    100.000000   75.000000  2215.000000     14.000000
# 50%     23.900000    145.000000   90.000000  2795.000000     15.500000
# 75%     30.700000    250.000000  115.000000  3504.000000     17.300000
# max     46.600000    455.000000  230.000000  4997.000000     24.800000

# %% [markdown]
# The range of mpg is 11-46, std is 7.908184 and mean is 24.438629. The displacement range is 68-455, std is 99.635385, and mean is 187.049. Horsepower range is 46-230, std is 35.896, mean is 100.956. Weight range is 1649-4997, std is 810.642, mean is 2933.963. Acceleration range is 8.5-24.8, std is 2.680, amd mean is 15.723.

# %% [markdown]
# E

# %%
pd.plotting.scatter_matrix(Auto[["mpg", "displacement", "horsepower", "weight", "acceleration"]], figsize=(10, 10))
plt.show()

# %% [markdown]
# Looking at mpg vs acceleration, yoou can see that the graphs are all over the place. A lot of the graphs are also linear positive relationships in the grid, like weight vs displacement, horsepower vs displacement, weight vs displacement, etc. A few of the graphs also look like a cloud.

# %% [markdown]
# F

# %% [markdown]
# Some variables that would be useful in predicting mpg would be weight and mpg. Both of these variables have a strong negative relationship with mpg and they can use that to predict mpg. Weight has the strongest and most linear relationship with mpg compared to the others(in my eyes, I could be wrong as I am basing it off of the graphs/grid).

# %% [markdown]
# 10

# %% [markdown]
# A

# %%
from google.colab import drive
drive.mount('/content/drive')
Boston = pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/Boston.csv", index_col=0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# B

# %%
Boston.shape
# Out:
# (506, 13)

# %%
Boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# The dataset has 506 rows and 13 columns with rows represent individual suburbs of Boston and columns represent different predictors/variables measured for each suburb.

# %% [markdown]
# C

# %%
pd.plotting.scatter_matrix(Boston[["tax","indus","crim",]], figsize=(7, 7))
plt.show()

# %% [markdown]
# Crim is extremely right-skewed ( which is on the bottom-right histogram): The vast majority of suburbs have a per-capita crime rate close to 0, but there's a long tail of a handful of suburbs with very high crime (which can go up to ~80–90). In the tax vs crim panel (top-right graph), we can notice that almost all the high-crime suburbs (the ones stretching up toward 80–90) sit at one specific tax value and is also right-shewed as well.

# %% [markdown]
# D

# %% [markdown]
# Some of the predictors do seem associcated with per capita crime rate. Looking at the scatterplots of crim against tax and indus, a clear pattern emerges: the suburbs with the highest crime rates (reaching up to 80–90) are not spread across the full range of tax or indus values. Instead, they cluster tightly around a tax rate of roughly ~650–670. While the suburbs with lower crime rates are spread across the entire range of both tax and indus.

# %% [markdown]
# E

# %%
Boston[["crim", "tax", "ptratio"]].describe()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# Yes, some of the suburbs have a high crime rates, crim ranges from 0.006 to 88.98, with a small number of suburbs having crime rates dramatically above the typical suburb ( with the mean 3.61 for crim). Tax ranges from 187 to 711; the highest tax rate (711) is shared by a block of suburbs rather than a single outlier. Ptratio has a comparatively narrow range (12.6 to 22.0) with no extreme outliers, so it is fairly consistent across Boston suburbs compared to the other variables.

# %% [markdown]
# F

# %%
Boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# G

# %%
Boston["ptratio"].median()
# Out:
# 19.05

# %% [markdown]
# H

# %%
Boston["medv"].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %%
Boston.loc[Boston["medv"] == 5]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 399     20.2  30.59   5.0
# 406     20.2  22.98   5.0

# %% [markdown]
# Looking at 399 and 406, they have extreme outliers on almost every predictor. Theye have high tax, rad, nox, indus and more. Suburb 406 also has a very high crime rate near the dataset's max. This is also connected with the other part earlier where high tax and indus values coincided with high crime.

# %% [markdown]
# I

# %%
(Boston["rm"] > 7).sum()
# Out:
# np.int64(64)

# %%
(Boston["rm"] > 8).sum()
# Out:
# np.int64(13)

# %%
Boston.loc[Boston["rm"] > 8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 98   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 225  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 227  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 233  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 234  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 254  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 258  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 263  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 268  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %% [markdown]
# 64 suburbs have an average of more than 7 rooms per dwelling, and 13 have more than 8. The 13 suburbs has low crime rates, low lstat, and lower pupil-teacher ratios. The 13 suburbs are the suburbs that is characterized by high median home values. There is one exception being the 365 one has it has very high tax high indus, and high rad compared to the others.
#
# ---
